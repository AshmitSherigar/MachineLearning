# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("student_depression_dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
np.round(df.describe(),0)
# Out:
#               id       Age  Academic Pressure  Work Pressure      CGPA  \
# count   27901.00  27901.00           27901.00       27901.00  27901.00
# mean    70442.15     25.82               3.14           0.00      7.66
# std     40641.18      4.91               1.38           0.04      1.47
# min         2.00     18.00               0.00           0.00      0.00
# 25%     35039.00     21.00               2.00           0.00      6.29
# 50%     70684.00     25.00               3.00           0.00      7.77
# 75%    105818.00     30.00               4.00           0.00      8.92
# max    140699.00     59.00               5.00           5.00     10.00
#
#        Study Satisfaction  Job Satisfaction  Work/Study Hours  Depression
# count            27901.00          27901.00          27901.00    27901.00
# mean                 2.94              0.00              7.16        0.59
# std                  1.36              0.04              3.71        0.49
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x = "Academic Pressure" , data = df)
# Out:
# <Axes: xlabel='Academic Pressure', ylabel='count'>

# %%
sns.countplot(x = "Have you ever had suicidal thoughts ?" , data = df)
# Out:
# <Axes: xlabel='Have you ever had suicidal thoughts ?', ylabel='count'>

# %%
sns.countplot(x = "Depression" , data = df)
# Out:
# <Axes: xlabel='Depression', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Work/Study Hours"],bins=20)
# Out:
# (array([1700., 1150.,    0., 1590.,    0., 1470., 1614.,    0., 1296.,
#            0., 2247., 2001.,    0., 2509.,    0., 2026., 4234.,    0.,
#         2892., 3172.]),
#  array([ 0. ,  0.6,  1.2,  1.8,  2.4,  3. ,  3.6,  4.2,  4.8,  5.4,  6. ,
#          6.6,  7.2,  7.8,  8.4,  9. ,  9.6, 10.2, 10.8, 11.4, 12. ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(df["CGPA"] , kde = True)
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df["CGPA"])
# Out:
# <Axes: ylabel='CGPA'>

# %%
sns.boxplot(df["Work/Study Hours"])
# Out:
# <Axes: ylabel='Work/Study Hours'>

# %% [markdown]
#  # BiVariate or MultiVariate

# %%
# sns.scatterplot( y = df["Age"] , x = df["Depression"],hue=df["Gender"])
# sns.scatterplot( y = df["CGPA"] , x = df["Depression"],hue=df["Gender"])
# Out:
# <Axes: xlabel='Depression', ylabel='Gender'>

# %%
sns.boxplot(x="Depression", y="CGPA", data=df)
plt.title("CGPA vs Depression")
plt.show()

# %%
sns.boxplot(x="Depression", y="Age", data=df)
plt.title("CGPA vs Age")
plt.show()

# %%
# sns.scatterplot( y = df["Financial Stress"] , x = df["Depression"],hue=df["Gender"])
sns.scatterplot( y = df["Academic Pressure"] , x = df["CGPA"],hue=df["Gender"])
# Out:
# <Axes: xlabel='CGPA', ylabel='Academic Pressure'>

# %%
sns.heatmap(pd.crosstab(df["Age"],df["Depression"]))
# Out:
# <Axes: xlabel='Depression', ylabel='Age'>

# %%
sns.pairplot(df,hue= 'Gender')

# %%
df['CGPA'].corr(df['Academic Pressure'])
# Out:
# -0.022238849696491852

# %%
selected = df[['CGPA', 'Work/Study Hours']]
sns.heatmap(selected.corr(), annot=True, cmap="coolwarm")
plt.title("CGPA vs Academic Pressure Correlation")
plt.show()
